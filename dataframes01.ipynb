# %%
import pandas as pd

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\LEGiON\AppData\Local\Programs\Python\Python37-32\Scripts

# %%
stats= pd.read_csv ('C:\\Users\\LEGiON\\AppData\\Local\\Programs\\Python\\P4-Demographic-Data.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
len(stats)
# Out:
# 195

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
len(stats.columns)
# Out:
# 5

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.head(99)
# Out:
#             Country Name Country Code  Birth rate  Internet users  \
# 0                  Aruba          ABW      10.244           78.90
# 1            Afghanistan          AFG      35.253            5.90
# 2                 Angola          AGO      45.985           19.10
# 3                Albania          ALB      12.877           57.20
# 4   United Arab Emirates          ARE      11.044           88.00
# ..                   ...          ...         ...             ...
# 94              Kiribati          KIR      29.044           11.50
# 95           Korea, Rep.          KOR       8.600           84.77
# 96                Kuwait          KWT      20.575           75.46
# 97               Lao PDR          LAO      27.051           12.50
# 98               Lebanon          LBN      13.426           70.50
#
#            Income Group
# 0           High income
# 1            Low income
# 2   Upper middle income
# 3   Upper middle income
# 4           High income
# ...

# %%
stats.head(8)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
# 6               Armenia          ARM      13.308            41.9
# 7   Antigua and Barbuda          ATG      16.447            63.4
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income

# %%
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %% [markdown]
# #renaming

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns =['a','b','c','d','e']

# %%
stats.head()
# Out:
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
stats.columns = ['Country Name', 'Country Code', 'Birth rate', 'Internet users',
       'Income Group']

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['Country Name']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: Country Name, Length: 195, dtype: object

# %%
stats[20:40]
# Out:
#                 Country Name Country Code  Birth rate  Internet users  \
# 20                   Belarus          BLR      12.500           54.17
# 21                    Belize          BLZ      23.092           33.60
# 22                   Bermuda          BMU      10.400           95.30
# 23                   Bolivia          BOL      24.236           36.94
# 24                    Brazil          BRA      14.931           51.04
# 25                  Barbados          BRB      12.188           73.00
# 26         Brunei Darussalam          BRN      16.405           64.50
# 27                    Bhutan          BTN      18.134           29.90
# 28                  Botswana          BWA      25.267           15.00
# 29  Central African Republic          CAF      34.076            3.50
# 30                    Canada          CAN      10.900           85.80
# 31               Switzerland          CHE      10.200           86.34
# ...

# %%
stats[80:100][['Country Name','Internet users']]
# Out:
#           Country Name  Internet users
# 80               India         15.1000
# 81             Ireland         78.2477
# 82  Iran, Islamic Rep.         29.9500
# 83                Iraq          9.2000
# 84             Iceland         96.5468
# 85              Israel         70.8000
# 86               Italy         58.4593
# 87             Jamaica         37.1000
# 88              Jordan         41.0000
# 89               Japan         89.7100
# 90          Kazakhstan         54.0000
# 91               Kenya         39.0000
# 92     Kyrgyz Republic         23.0000
# 93            Cambodia          6.8000
# 94            Kiribati         11.5000
# 95         Korea, Rep.         84.7700
# 96              Kuwait         75.4600
# 97             Lao PDR         12.5000
# 98             Lebanon         70.5000
# 99             Liberia          3.2000

# %%
stats.columns =['CountryName',
'CountryCode',
'Birthrate',
'Internetusers',
'IncomeGroup']

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'Birthrate', 'Internetusers',
#        'IncomeGroup'],
#       dtype='object')

# %%
multiply = stats.Birthrate * stats.Internetusers

# %%
multiply
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.Internetusers <10
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: Internetusers, Length: 195, dtype: bool

# %%
Filter = stats.Internetusers <10

# %%
Filter
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: Internetusers, Length: 195, dtype: bool

# %%
stats[Filter]
# Out:
#                   CountryName CountryCode  Birthrate  Internetusers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 15                 Bangladesh         BGD     20.142           6.63
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 46                   Djibouti         DJI     25.486           9.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# ...
