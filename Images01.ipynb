# %% [markdown]
# # IMAGE

# %%
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-7892611e7a30> in <module>
# ----> 1 from PIL import image
#
# ImportError: cannot import name 'image' from 'PIL' (c:\users\legion\appdata\local\programs\python\python37-32\lib\site-packages\PIL\__init__.py)

# %%
a=Image.open('pythonlogo.png')

# %%
a
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=920x500 at 0x68BCEB0>

# %%
a.size
# Out:
# (920, 500)

# %%
a.width
# Out:
# 920

# %%
a.filename
# Out:
# 'pythonlogo.png'

# %%
a.format_description
# Out:
# 'Portable network graphics'

# %% [markdown]
# # CROPPING A IMAGE

# %%
a.crop((20,40,250,400))
# Out:
# <PIL.Image.Image image mode=P size=230x360 at 0x7685050>

# %%
b=a.crop((20,40,250,400))

# %%
a.paste(im=b,box=(500,0))

# %%
a
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=920x500 at 0x68BCEB0>

# %%
b
# Out:
# <PIL.Image.Image image mode=P size=230x360 at 0x768CAB0>

# %%
b.resize((1000,1000))
# Out:
# <PIL.Image.Image image mode=P size=1000x1000 at 0x6466250>

# %%
b.resize((20,20))
# Out:
# <PIL.Image.Image image mode=P size=20x20 at 0x6466DB0>

# %%
b.rotate(45)
# Out:
# <PIL.Image.Image image mode=P size=230x360 at 0x6466EF0>
