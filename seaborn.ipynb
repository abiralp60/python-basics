# %% [markdown]
# # seaborn

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd

# %%
stats=pd.read_csv('C:\\Users\\LEGiON\\AppData\\Local\\Programs\\Python\\P4-Demographic-Data.csv')

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# distribution

# %%
vis1= sns.distplot(stats["Internet users"])

# %%
vis1= sns.distplot(stats["Internet users"], bins=50)

# %%
vis1= sns.distplot(stats["Internet users"],bins=2)

# %%
import seaborn as sns
vis2= sns.boxplot(data=stats ,x="Income Group" , y="Birth rate")

# %% [markdown]
# seaborn gallery

# %%
vis3=sns.lmplot(data=stats, x="Internet users",y="Birth rate" )
